# %%
#test
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm
import json
import csv


# from config import api_keys
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"
final_output_data_file = "output_data/cities_final.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# # List for holding lat_lngs and cities
# lat_lngs = []
# cities = []

# # Create a set of random lat and lng combinations
# lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
# lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
# lat_lngs = zip(lats, lngs)

# # Identify nearest city for each lat, lng combination
# for lat_lng in lat_lngs:
#     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
#     # If the city is unique, then add it to a our cities list
#     if city not in cities:
#         cities.append(city)

# # Print the city count to confirm sufficient count
# len(cities)

### Saving out the city pull [swithcer between the full and 10]

# Switch the # between the next two lines to get ether all of the cities or just the first 10

# all cities
# cities_df = pd.DataFrame(cities, columns=["city"])

# # Just the first 10 cities
# cities_df = pd.DataFrame(cities[:10], columns=["city"])


# # Creates the CSV file
# cities_df.to_csv(output_data_file, header=False, index=False)

colnames = ['city']
data = pd.read_csv(output_data_file, names=colnames)
cities_list = data.city.tolist()

# removes the word Cities from our list
del cities_list[0]
# print(cities_list)

# Create settings dictionary with information we're interested in
# settings = {"units": "Fahrenheit", "appid": api_key}
# settings = {"appid": api_key, "&units=": "fahrenheit"}
# settings = {"units": "imperial", "appid": api_key}
# &units=
# units = ["Fahrenheit"]

# query_url = "https://api.openweathermap.org/data/2.5/weather?q="

#create columns to hold data in df
data['Cloudiness'] = ""
data['Country'] = ""
data['Date'] = ""
data['Humidity'] = ""
data['Lat'] = ""
data['Long'] = ""
data['Max Temp'] = ""
data['Wind Speed'] = ""
data

cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
max_temp = []
wind_speed = []

url = "https://api.openweathermap.org/data/2.5/weather?q="
query_url = url + cities[index] + "&units=Imperial&APPID=" + api_key

number = [i for i in range(50)]
set_number = [i for i in range(50)]
results = []

print("Begining Data Retrieval")
print("-----------------------")

for index, row in data.iterrows():

    # assemble url and make API request
    ############## settings did not work so did query_url 
    response = requests.get(query_url).json()
    #response_json = response.json()
    long.append(response["coord"]["lon"])
    print(long)
    
#     # add keyword to params dict
#     params['keyword'] = cities

    #print(json.dumps(response_json, indent=4, sort_keys=True))
  
# use as an example
# for show in shows:
#     response = requests.get(url + tv_shows).json()
#     rating.append(response['rating'])    
    
    #go back and check page 115
    #data.loc[index, "cloudiness"] = response_json[index]["clouds.all"]
    
    #GOOD###
#     data.loc[index, long] = response_json["coord"]["lon"]
#     lat = response_json["coord"]["lat"]
#     max_temp = response_json["main"]["temp_max"]
#     humidity = response_json["main"]["humidity"]
#     wind_speed = response_json["wind"]["speed"]
#     cloudiness = response_json["clouds"]["all"]
#     date = response_json["dt"]
#     country = response_json["sys"]["country"]

#from my other file that worked but tutor didn't like
#         cities_df.loc[index, 'Lng'] = response["coord"]["lon"]
#         cities_df.loc[index, 'Lat'] = response["coord"]["lat"]
#         cities_df.loc[index, 'Max Temp'] = response["main"]["temp_max"]
#         cities_df.loc[index, 'Humidity'] = response["main"]["humidity"]
#         cities_df.loc[index, 'Wind Speed'] = response["wind"]["speed"]
#         cities_df.loc[index, 'Cloudiness'] = response["clouds"]["all"]
#         cities_df.loc[index, 'Date'] = response["dt"]
#         cities_df.loc[index, 'Country'] = response["sys"]["country"]

    
    try:
        print(f"Processing Record {number[index]} of Set {set_number[0]} | {cities[index]}")
        print(f"{url}units=Imperial&APPID={api_key}&q={cities[index]}")
        

        
    except (HTTPError):
        print("City not found. Skipping...") 

weather_data = pd.DataFrame({"City" : data,
                             "Cloudiness" : [cloudiness], 
                             "Country" : [country], 
                             "Date" : [date],
                             "Humidity" : [humidity],
                             "Lat" : [lat],
                             "Long" : [long],
                             "Max Temp" : [max_temp], 
                             "Wind Speed" : [wind_speed]})
                                      
weather_data.head()
                                      
##################################################################################################################################
##################################################################################################################################
# summary = ["name", "clouds.all", "sys.country", "dt", "main.humidity", "coord.lat", "coord.lon", "main.temp_max", "wind.speed"]
# data = [response(*summary) for response in weather_data]

# weather_data = pd.DataFrame(data)
# # weather_data = pd.DataFrame(data, index=cities)
# weather_data.columns = ["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]
# Out:
# Begining Data Retrieval
# -----------------------
# [-114.38]
# Processing Record 0 of Set 0 | bredasdorp
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=bredasdorp
# [-114.38, -114.38]
# Processing Record 1 of Set 0 | puerto escondido
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=puerto escondido
# [-114.38, -114.38, -114.38]
# Processing Record 2 of Set 0 | brokopondo
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=brokopondo
# [-114.38, -114.38, -114.38, -114.38]
# Processing Record 3 of Set 0 | aykhal
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=aykhal
# [-114.38, -114.38, -114.38, -114.38, -114.38]
# Processing Record 4 of Set 0 | rikitea
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=rikitea
# [-114.38, -114.38, -114.38, -114.38, -114.38, -114.38]
# Processing Record 5 of Set 0 | los llanos de aridane
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=los llanos de aridane
# [-114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38]
# Processing Record 6 of Set 0 | lavrentiya
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=lavrentiya
# [-114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38]
# Processing Record 7 of Set 0 | arraial do cabo
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=arraial do cabo
# [-114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38]
# Processing Record 8 of Set 0 | praia
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=praia
# [-114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38, -114.38]
# Processing Record 9 of Set 0 | yellowknife
# https://api.openweathermap.org/data/2.5/weather?q=units=Imperial&APPID=7ea5b12534a46c163f6800064e7d756a&q=yellowknife
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4872         blocks = form_blocks(arrays, names, axes)
# -> 4873         mgr = BlockManager(blocks, axes)
#    4874         mgr._consolidate_inplace()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in __init__(self, blocks, axes, do_integrity_check)
#    3281         if do_integrity_check:
# -> 3282             self._verify_integrity()
#    3283
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in _verify_integrity(self)
#    3492             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3493                 construction_error(tot_items, block.shape[1:], self.axes)
#    3494         if len(self.items) != tot_items:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#
# ValueError: Shape of passed values is (9, 9), indices imply (9, 1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-fa6aa6e80279> in <module>()
#     156                              "Long" : [long],
#     157                              "Max Temp" : [max_temp],
# --> 158                              "Wind Speed" : [wind_speed]})
#     159
#     160 weather_data.head()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7362     axes = [_ensure_index(columns), _ensure_index(index)]
#    7363
# -> 7364     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    7365
#    7366
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4875         return mgr
#    4876     except ValueError as e:
# -> 4877         construction_error(len(arrays), arrays[0].shape, axes, e)
#    4878
#    4879
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in construction_error(tot_items, block_shape, axes, e)
#    4841         raise ValueError("Empty data passed with indices specified.")
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#    4845
#
# ValueError: Shape of passed values is (9, 9), indices imply (9, 1)
